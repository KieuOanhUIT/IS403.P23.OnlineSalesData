# %% [markdown]
# Import thư viện và đọc dữ liệu

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt
import xgboost as xgb
import seaborn as sns
import matplotlib.dates as mdates
from datetime import timedelta

# Load data
train_df = pd.read_csv("../Dataset/train1.csv", parse_dates=["date"])
valid_df = pd.read_csv("../Dataset/validation1.csv", parse_dates=["date"])
test_df = pd.read_csv("../Dataset/test1.csv", parse_dates=["date"])

# %% [markdown]
# Lựa chọn đặc trưng và target

# %%
features = ['daily_tickets', 'daily_used_tickets', 'avg_occupancy',	'unique_films',	'unique_cinemas', 'month', 'quarter', 'day', 'year']
target = 'daily_sales'

X_train = train_df[features].values
y_train = train_df[target].values
X_valid = valid_df[features].values
y_valid = valid_df[target].values
X_test = test_df[features].values
y_test = test_df[target].values

# %% [markdown]
# Chuẩn hóa dữ liệu

# %%
scaler_X = StandardScaler()
scaler_y = StandardScaler()
X_train = scaler_X.fit_transform(X_train)
y_train = scaler_y.fit_transform(y_train.reshape(-1, 1)).flatten()
X_valid = scaler_X.transform(X_valid)
y_valid = scaler_y.transform(y_valid.reshape(-1, 1)).flatten()
X_test = scaler_X.transform(X_test)
y_test = scaler_y.transform(y_test.reshape(-1, 1)).flatten()

# %% [markdown]
# Huấn luyện mô hình

# %%
# Khởi tạo DMatrix
dtrain = xgb.DMatrix(X_train, label=y_train)
dvalid = xgb.DMatrix(X_valid, label=y_valid)
dtest = xgb.DMatrix(X_test, label=y_test)

# Tham số mô hình
params = {
    'objective': 'reg:squarederror',
    'learning_rate': 0.1,
    'max_depth': 6,
    'booster': 'gbtree',
    'verbosity': 0,
}

# Huấn luyện mô hình với early stopping
evals = [(dtrain, 'train'), (dvalid, 'eval')]
booster = xgb.train(
    params=params,
    dtrain=dtrain,
    num_boost_round=500,              # số vòng tối đa
    evals=evals,
    early_stopping_rounds=20,         # dừng nếu eval không cải thiện sau 20 vòng
    verbose_eval=True
)
# Out:
# [0]	train-rmse:0.91010	eval-rmse:0.75113
# [1]	train-rmse:0.82906	eval-rmse:0.67990
# [2]	train-rmse:0.75575	eval-rmse:0.60769
# [3]	train-rmse:0.68946	eval-rmse:0.55118
# [4]	train-rmse:0.62897	eval-rmse:0.49697
# [5]	train-rmse:0.57414	eval-rmse:0.44712
# [6]	train-rmse:0.52451	eval-rmse:0.40577
# [7]	train-rmse:0.47981	eval-rmse:0.38059
# [8]	train-rmse:0.43870	eval-rmse:0.34695
# [9]	train-rmse:0.40160	eval-rmse:0.33225
# [10]	train-rmse:0.36819	eval-rmse:0.30804
# [11]	train-rmse:0.33758	eval-rmse:0.28400
# [12]	train-rmse:0.30989	eval-rmse:0.27464
# [13]	train-rmse:0.28464	eval-rmse:0.25992
# [14]	train-rmse:0.26178	eval-rmse:0.25299
# [15]	train-rmse:0.24085	eval-rmse:0.24365
# [16]	train-rmse:0.22170	eval-rmse:0.23912
# [17]	train-rmse:0.20441	eval-rmse:0.22966
# [18]	train-rmse:0.18881	eval-rmse:0.22603
# [19]	train-rmse:0.17465	eval-rmse:0.21979
# [20]	train-rmse:0.16169	eval-rmse:0.21523
# [21]	train-rmse:0.14992	eval-rmse:0.21022
# [22]	train-rmse:0.13915	eval-rmse:0.20554
# [23]	train-rmse:0.12934	eval-rmse:0.20081
# [24]	train-rmse:0.12039	eval-rmse:0.19877
# [25]	train-rmse:0.11227	eval-rmse:0.19556
# [26]	train-rmse:0.10460	eval-rmse:0.19346
# [27]	train-rmse:0.09779	eval-rmse:0.19068
# [28]	train-rmse:0.09126	eval-rmse:0.19018
# [29]	train-rmse:0.08535	eval-rmse:0.18862
# [30]	train-rmse:0.07998	eval-rmse:0.18703
# [31]	train-rmse:0.07509	eval-rmse:0.18496
# [32]	train-rmse:0.07049	eval-rmse:0.18281
# [33]	train-rmse:0.06649	eval-rmse:0.18209
# [34]	train-rmse:0.06267	eval-rmse:0.18168
# [35]	train-rmse:0.05932	eval-rmse:0.18119
# [36]	train-rmse:0.05572	eval-rmse:0.18041
# [37]	train-rmse:0.05281	eval-rmse:0.18022
# [38]	train-rmse:0.04983	eval-rmse:0.17881
# [39]	train-rmse:0.04699	eval-rmse:0.17837
# [40]	train-rmse:0.04441	eval-rmse:0.17814
# [41]	train-rmse:0.04200	eval-rmse:0.17754
# [42]	train-rmse:0.03984	eval-rmse:0.17692
# [43]	train-rmse:0.03783	eval-rmse:0.17648
# [44]	train-rmse:0.03569	eval-rmse:0.17620
# [45]	train-rmse:0.03366	eval-rmse:0.17524
# [46]	train-rmse:0.03223	eval-rmse:0.17532
# [47]	train-rmse:0.03046	eval-rmse:0.17449
# [48]	train-rmse:0.02888	eval-rmse:0.17364
# [49]	train-rmse:0.02743	eval-rmse:0.17274
# [50]	train-rmse:0.02613	eval-rmse:0.17241
# [51]	train-rmse:0.02510	eval-rmse:0.17172
# [52]	train-rmse:0.02399	eval-rmse:0.17158
# [53]	train-rmse:0.02291	eval-rmse:0.17075
# [54]	train-rmse:0.02193	eval-rmse:0.17038
# [55]	train-rmse:0.02109	eval-rmse:0.17017
# [56]	train-rmse:0.02017	eval-rmse:0.16969
# [57]	train-rmse:0.01939	eval-rmse:0.16925
# [58]	train-rmse:0.01869	eval-rmse:0.16893
# [59]	train-rmse:0.01782	eval-rmse:0.16867
# [60]	train-rmse:0.01702	eval-rmse:0.16854
# [61]	train-rmse:0.01641	eval-rmse:0.16853
# [62]	train-rmse:0.01583	eval-rmse:0.16822
# [63]	train-rmse:0.01523	eval-rmse:0.16823
# [64]	train-rmse:0.01474	eval-rmse:0.16817
# [65]	train-rmse:0.01428	eval-rmse:0.16811
# [66]	train-rmse:0.01356	eval-rmse:0.16812
# [67]	train-rmse:0.01289	eval-rmse:0.16813
# [68]	train-rmse:0.01229	eval-rmse:0.16816
# [69]	train-rmse:0.01173	eval-rmse:0.16821
# [70]	train-rmse:0.01133	eval-rmse:0.16823
# [71]	train-rmse:0.01099	eval-rmse:0.16820
# [72]	train-rmse:0.01069	eval-rmse:0.16820
# [73]	train-rmse:0.01036	eval-rmse:0.16801
# [74]	train-rmse:0.00987	eval-rmse:0.16801
# [75]	train-rmse:0.00965	eval-rmse:0.16798
# [76]	train-rmse:0.00944	eval-rmse:0.16795
# [77]	train-rmse:0.00927	eval-rmse:0.16794
# [78]	train-rmse:0.00885	eval-rmse:0.16780
# [79]	train-rmse:0.00872	eval-rmse:0.16781
# [80]	train-rmse:0.00860	eval-rmse:0.16780
# [81]	train-rmse:0.00849	eval-rmse:0.16780
# [82]	train-rmse:0.00821	eval-rmse:0.16785
# [83]	train-rmse:0.00796	eval-rmse:0.16788
# [84]	train-rmse:0.00783	eval-rmse:0.16785
# [85]	train-rmse:0.00766	eval-rmse:0.16786
# [86]	train-rmse:0.00746	eval-rmse:0.16783
# [87]	train-rmse:0.00726	eval-rmse:0.16781
# [88]	train-rmse:0.00713	eval-rmse:0.16783
# [89]	train-rmse:0.00689	eval-rmse:0.16796
# [90]	train-rmse:0.00678	eval-rmse:0.16800
# [91]	train-rmse:0.00667	eval-rmse:0.16799
# [92]	train-rmse:0.00658	eval-rmse:0.16806
# [93]	train-rmse:0.00640	eval-rmse:0.16804
# [94]	train-rmse:0.00626	eval-rmse:0.16806
# [95]	train-rmse:0.00618	eval-rmse:0.16810
# [96]	train-rmse:0.00611	eval-rmse:0.16814
# [97]	train-rmse:0.00605	eval-rmse:0.16818
# [98]	train-rmse:0.00599	eval-rmse:0.16820
# [99]	train-rmse:0.00591	eval-rmse:0.16820
# [100]	train-rmse:0.00579	eval-rmse:0.16816

# %% [markdown]
# Đánh giá mô hình

# %%
# Dự đoán tập test
test_preds_scaled = booster.predict(dtest)
test_preds = scaler_y.inverse_transform(test_preds_scaled.reshape(-1, 1)).flatten()
test_targets = scaler_y.inverse_transform(y_test.reshape(-1, 1)).flatten()

# Tính metrics
mae = mean_absolute_error(test_targets, test_preds)
rmse = mean_squared_error(test_targets, test_preds, squared=False)
r2 = r2_score(test_targets, test_preds)

print(f"Test MAE: {mae:.2f}")
print(f"Test RMSE: {rmse:.2f}")
print(f"Test R²: {r2:.4f}")
# Out:
# Test MAE: 1057629073.12
# Test RMSE: 1648858995.70
# Test R²: 0.8648
# c:\Users\QUYEN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %% [markdown]
# So sánh doanh thu thực tế với dự đoán

# %%
# Vẽ biểu đồ so sánh thực tế và dự đoán
plt.figure(figsize=(10,5))
plt.plot(test_targets[:100], label='Actual')
plt.plot(test_preds[:100], label='Predicted')
plt.legend()
plt.title('Doanh thu thực tế với dự đoán')
plt.xlabel('Sample')
plt.ylabel('Total Sales')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.plot(train_losses, label='Train Loss')
plt.plot(valid_losses, label='Valid Loss')
plt.legend()
plt.title('Loss theo epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.show()

# %% [markdown]
# Dự đoán 30 ngày tương lai

# %%
# ===== DỰ ĐOÁN 30 NGÀY TƯƠNG LAI =====
df = pd.read_csv('../Dataset/cinema_daily_sales.csv', parse_dates=['date'])
last_30_days = df.iloc[-30:].copy()
last_date = df['date'].iloc[-1]
future_dates = pd.date_range(start=last_date + timedelta(days=1), periods=30).strftime('%Y-%m-%d')

# Chuẩn bị dữ liệu dự đoán
future_X_raw = last_30_days[features].values
future_X_scaled = scaler_X.transform(future_X_raw)
future_dmatrix = xgb.DMatrix(future_X_scaled)
future_preds_scaled = booster.predict(future_dmatrix)
future_sales = scaler_y.inverse_transform(future_preds_scaled.reshape(-1, 1)).flatten()

# Tạo DataFrame dự đoán
future_df = pd.DataFrame({
    'date': future_dates,
    'daily_sales': future_sales,
    'type': 'Forecasted Sales'
})

# Gộp với dữ liệu cũ
df['type'] = 'Past Sales'
combined_df = pd.concat([df, future_df], ignore_index=True)

# Vẽ biểu đồ
plt.figure(figsize=(16, 8))
sns.lineplot(
    data=combined_df,
    x='date',
    y='daily_sales',
    hue='type',
    style='type',
    dashes=False,
    palette={
        'Past Sales': 'blue',
        'Forecasted Sales': 'red'
    },
    linewidth=2.5
)
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.xticks(rotation=45)
plt.xlabel('Date')
plt.ylabel('Daily Sales')
plt.title('Sales Forecasting with XGBoost')
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend(title='Data Type')
plt.tight_layout()
plt.show()

# Xuất kết quả
future_df[['date', 'daily_sales']].rename(columns={'date': 'Date', 'daily_sales': 'Predicted Sales'})
# Out:
#           Date  Predicted Sales
# 0   2018-11-05     9.458632e+09
# 1   2018-11-06     3.937669e+09
# 2   2018-11-07     3.295453e+09
# 3   2018-11-08     1.108472e+10
# 4   2018-11-09     7.442773e+09
# 5   2018-11-10     1.183400e+10
# 6   2018-11-11     1.448888e+10
# 7   2018-11-12     5.915652e+09
# 8   2018-11-13     4.186706e+09
# 9   2018-11-14     3.983429e+09
# 10  2018-11-15     1.253775e+10
# 11  2018-11-16     7.095096e+09
# 12  2018-11-17     1.151390e+10
# 13  2018-11-18     1.047792e+10
# 14  2018-11-19     9.013028e+09
# 15  2018-11-20     4.089598e+09
# 16  2018-11-21     3.942503e+09
# 17  2018-11-22     1.091349e+10
# 18  2018-11-23     6.896902e+09
# 19  2018-11-24     1.137735e+10
# 20  2018-11-25     1.081502e+10
# 21  2018-11-26     6.578742e+09
# 22  2018-11-27     4.006584e+09
# 23  2018-11-28     4.001190e+08
# 24  2018-11-29     3.406568e+07
# 25  2018-11-30     5.355565e+09
# 26  2018-12-01     8.928412e+09
# 27  2018-12-02     8.316832e+09
# 28  2018-12-03     4.425975e+09
# 29  2018-12-04     2.957315e+08
